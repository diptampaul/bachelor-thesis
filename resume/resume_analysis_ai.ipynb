# %%
import sys
import fitz
fname = "DIPTAM PAUL CV.pdf"
doc = fitz.open(fname)
text = ""
for page in doc:
    text = text + str(page.getText())

text = text.replace('o ','')
text = text.replace('|','')

# %%
text
# Out:
# "  -        https://udemy.com/user/diptam-paul/\nONLINE PROFILE:\n  -        https://github.com/diptampaul/\n  -        https://linkedin.com/in/diptam-paul/\nEMPLOYMENT BACKGROUND\n- Wrote code for Google Auth permissions tintegrate Youtube and Google Drive\n- Made blog on different Python Topics for codespeedy.com\nPython Developer Internship\nCodeSpeedy Pvt Ltd  Jan 2020 - Mar 2020\nDIPTAM PAUL\nD A T A  S C I E N T I S T    F U L L  S T A C K  D E V  \nPERSONAL SUMMARY\nI'm a Data Science grad student at Indian\nInstitute of Technology, Madras. I have\nhands-on experience in computer vision,\nmachine learning, data analysis, deep\nlearning tsolve challenging business\nproblems\nACHIEVEMENTS\n- Winner at Biomimicry Jam at Research\nScholar Day - 2021 : We found out egg shells\ncan replace the plastic carry bags and\nmushrooms can replace the plastic cap on\nevery pen.\n- Came up with Adaptive Quiz System\nusing Djangtadapt the student's\nbehavior in the exam tgive more\ncustomized 
# ...

# %% [markdown]
# ### Import and Autheticate to Service

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, RelationsOptions, CategoriesOptions, EmotionOptions, KeywordsOptions

# %%
# apikey = 'hh0wloMs30Oi7IhItDcBQqRWDNyueiOeO_xJfpECT7fK'
# url = 'https://api.au-syd.personality-insights.watson.cloud.ibm.com/instances/4c047b10-8967-4e28-a32f-8f88ea2c753a'

#NLU API
apikey = 'RNk3uMx9YZLEZqpVjmkEKfzG1j3AK3Vx1wxr4pyRsBXW'
url = 'https://api.jp-tok.natural-language-understanding.watson.cloud.ibm.com/instances/b7d1a215-b7dd-49a9-9de0-bfe159c8972f'

# %%
# Authenticate to PI service
authenticator = IAMAuthenticator(apikey)
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2021-08-01',
    authenticator=authenticator
)
natural_language_understanding.set_service_url(url)

# %% [markdown]
# ### Extract Resumee

# %%
response = natural_language_understanding.analyze(
    text=text,
    features=Features(emotion=EmotionOptions())).get_result()
response
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\Users\dipta\Desktop\7th sem project\env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\Users\dipta\Desktop\7th sem project\env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# C:\Python39\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# --> 953     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954         af, socktype, proto, canonname, sa = res
#
# ...

# %%
response = natural_language_understanding.analyze(
    text=text,
    features=Features(keywords=KeywordsOptions(sentiment=True,emotion=True))).get_result()

response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 3175, 'features': 1},
#  'language': 'en',
#  'keywords': [{'text': 'T A  S C',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.640844,
#    'emotion': {'sadness': 0.427032,
#     'joy': 0.00826,
#     'fear': 0.344285,
#     'disgust': 0.057496,
#     'anger': 0.121328},
#    'count': 1},
#   {'text': 'Data Science',
#    'sentiment': {'score': 0.799081, 'label': 'positive'},
#    'relevance': 0.595043,
#    'emotion': {'sadness': 0.087259,
#     'joy': 0.756256,
#     'fear': 0.031137,
#     'disgust': 0.018672,
#     'anger': 0.057026},
#    'count': 2},
#   {'text': 'machine learning',
#    'sentiment': {'score': 0.502993, 'label': 'positive'},
#    'relevance': 0.594977,
#    'emotion': {'sadness': 0.167462,
#     'joy': 0.223329,
#     'fear': 0.15796,
#     'disgust': 0.015981,
#     'anger': 0.10145},
#    'count': 2},
#   {'text': 'Data Science grad student',
# ...
